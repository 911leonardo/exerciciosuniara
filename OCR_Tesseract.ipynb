# %% [markdown]
# <a href="https://colab.research.google.com/github/911leonardo/exerciciosuniara/blob/main/OCR_Tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# !sudo apt-get install -y tesseract-ocr-por
# !pip install pillow
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (8,194 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !tesseract --list-langs
# Out:
# List of available languages (3):
# eng
# osd
# por

# %%
# Importar bibliotecas necessárias
import pytesseract
from PIL import Image
import requests
from io import BytesIO

# imagem de exemplo
imagemdados = ['image1','image2','image3','image4','image5','image6','image7','image8','image9','image10','image11','image12','image13','image14','image15','image16','image17','image18','image19','image20']
for n in imagemdados:
  img = '/content/'+ n +'.png'
  texto = pytesseract.image_to_string(img, lang='por')
  print(n + ': ')
  print(texto)
# Out:
# image1:
# ebeça, Compro maos a Bardo é ro banco par
# Tot da convés, os braços múlo branens
# our de origem É da mubar se vs
# cao Co E Gts tt demais,
# “gg 8 dis à rot e ale para o sau próprio
# una! 0 coque a pet. Dec
# ie tardia, Hc se quo (le
# SA alma deemem em auáts separados
# a Copo Es permanece de
# Br é um reg deus ms
#
#
#
# radar dk era, Teto sudo)
#
# image2:
# DE
# ERR ei
# a
#
# Você, esta pessoa especial que chegou de
#
# ESC N MeR top
# RSRS Peter ns
# E
# E rn
# de ser, o sorriso que me encanta.
#
# OR RETRO
#
# ERC
#
#
#
# image3:
# TEXTO LACUNADO
#
# o NGUAD O
# PORQUE NÃO QUER
# ta
#
# u um Do POMQUENHOQUER
#
#
#
# image4:
#
#
#
#
#
#
#
#
#
#
# image5:
#
#
#
#
#
#
#
#
#
#
# image6:
# como escrever un recto
# Meoiciahor 1 1 5 ao core
#
#
#
# re na sp
#
#
#
# image7:
#
#
# image8:
#
#
# image9:
#
# image10:
#
#
#
#
#
#
#
#
#
#
# image11:
#
#
# image12:
#
#
#
# 20
# IMAGENS PARA
#
# Produção de frases ou textos.
#
# image13:
# O Programa de PósGraduação em
# ...
